# %% [markdown]
# # Python3 Questions
#
# This notebook contains 20 programming tasks based on the techniques covered in `Python3.ipynb`. Work through them in order or use them as targeted refresher exercises by topic.

# %%
# %matplotlib inline

from pathlib import Path
import json
import csv
from collections import Counter, defaultdict, deque
from dataclasses import dataclass
from functools import reduce
from itertools import groupby
from statistics import mean

NOTEBOOK_DIR = Path.cwd().resolve()
GENERATED_DIR = NOTEBOOK_DIR / "generated_examples"
GENERATED_DIR.mkdir(exist_ok=True)
print(f"Working in {NOTEBOOK_DIR}")

# %% [markdown]
# ## Task List
#
# - 1. Truthiness Filter (bool and truthiness, list)
# - 2. String Normalization (str and Unicode text)
# - 3. Dictionary Inversion (dict, defaultdict)
# - 4. Conditional Classification (if / elif / else, comparison operators)
# - 5. Pattern Matching Command Parser (match / case)
# - 6. Keyword-Only Reporting Function (parameters, arguments, defaults, keyword-only arguments)
# - 7. Closure-Based Multiplier Factory (closures and nonlocal, first-class functions)
# - 8. Custom Iterable (iteration protocol)
# - 9. Equality and Hashing with Dataclasses (dataclasses, equality, ordering, and hashing)
# - 10. Safe Average with Exceptions (raising exceptions well, assertions and invariants)
# - 11. Pathlib File Summary (pathlib, safe file-handling patterns)
# - 12. JSON Serialization Task (json)
# - 13. Counter-Based Frequency Report (collections.Counter)
# - 14. Iterator Pipeline (iterator algebra with itertools, lazy vs eager evaluation)
# - 15. Protocol-Oriented Function (Protocol and structural typing)
# - 16. Enum-Based State Machine (enum)
# - 17. Logging Wrapper Decorator (decorators, logging)
# - 18. Dataclass Validation with Property (properties, dataclasses)
# - 19. Doctest-Friendly Utility (doctests)
# - 20. Small Unit Test Suite (unittest)

# %% [markdown]
# ## 1. Truthiness Filter
#
# **Techniques:** bool and truthiness, list
#
# - Write a function `keep_truthy(values)` that returns a new list containing only truthy values from the input iterable.
# - Do not mutate the original input.
# - Test it on `[0, 1, "", "python", [], [1, 2], None, True]`.

# %%
def keep_truthy(values):
    # Your code here
    pass


sample = [0, 1, "", "python", [], [1, 2], None, True]
print(keep_truthy(sample))

# %% [markdown]
# ## 2. String Normalization
#
# **Techniques:** str and Unicode text
#
# - Write a function `normalize_names(raw)` where `raw` is a comma-separated string of names with inconsistent spaces and casing.
# - Return a list of cleaned names in title case.
# - Example input: `" alice,BOB,  cara de souza "`.

# %%
def normalize_names(raw: str) -> list[str]:
    # Your code here
    pass


print(normalize_names(" alice,BOB,  cara de souza "))

# %% [markdown]
# ## 3. Dictionary Inversion
#
# **Techniques:** dict, defaultdict
#
# - Given a mapping from student name to cohort, build the inverse mapping from cohort to list of student names.
# - Preserve the original encounter order within each cohort.
# - Return a plain `dict`, even if you use `defaultdict` internally.

# %%
from collections import defaultdict


def invert_cohorts(student_to_cohort: dict[str, str]) -> dict[str, list[str]]:
    # Your code here
    pass


records = {"Alice": "A", "Bob": "B", "Cara": "A", "Dan": "B"}
print(invert_cohorts(records))

# %% [markdown]
# ## 4. Conditional Classification
#
# **Techniques:** if / elif / else, comparison operators
#
# - Write `classify_score(score)` that returns `"distinction"`, `"pass"`, or `"fail"`.
# - Use the rule: 70 and above is distinction, 50 to 69 is pass, below 50 is fail.
# - Raise `ValueError` if the score is outside `0..100`.

# %%
def classify_score(score: int) -> str:
    # Your code here
    pass


for score in [92, 67, 48]:
    print(score, classify_score(score))

# %% [markdown]
# ## 5. Pattern Matching Command Parser
#
# **Techniques:** match / case
#
# - Write `describe_command(command)` where `command` is a tuple such as `('move', 10, 20)` or `('say', "hello")`.
# - Use structural pattern matching to return a readable description string.
# - Return `"unknown command"` for unsupported patterns.

# %%
def describe_command(command: tuple) -> str:
    # Your code here
    pass


print(describe_command(("move", 10, 20)))
print(describe_command(("say", "hello")))
print(describe_command(("quit",)))

# %% [markdown]
# ## 6. Keyword-Only Reporting Function
#
# **Techniques:** parameters, arguments, defaults, keyword-only arguments
#
# - Write `format_report(name, score, *, rounded=False)`.
# - When `rounded=True`, the score should be displayed with no decimal places; otherwise show two decimal places.
# - Return the formatted string instead of printing it.

# %%
def format_report(name: str, score: float, *, rounded: bool = False) -> str:
    # Your code here
    pass


print(format_report("Alice", 91.345))
print(format_report("Alice", 91.345, rounded=True))

# %% [markdown]
# ## 7. Closure-Based Multiplier Factory
#
# **Techniques:** closures and nonlocal, first-class functions
#
# - Write `make_running_total()` that returns a function.
# - Each time the returned function is called with a number, it should add that number to an enclosed total and return the updated total.
# - Use `nonlocal` correctly.

# %%
def make_running_total():
    # Your code here
    pass


tracker = make_running_total()
print(tracker(5))
print(tracker(7))
print(tracker(-2))

# %% [markdown]
# ## 8. Custom Iterable
#
# **Techniques:** iteration protocol
#
# - Implement a class `Countdown` that is initialized with a positive integer.
# - Iterating over it should yield values down to `1`.
# - Implement the iterator protocol directly on the class.

# %%
class Countdown:
    def __init__(self, start: int):
        # Your code here
        pass

    def __iter__(self):
        # Your code here
        pass

    def __next__(self):
        # Your code here
        pass


print(list(Countdown(5)))

# %% [markdown]
# ## 9. Equality and Hashing with Dataclasses
#
# **Techniques:** dataclasses, equality, ordering, and hashing
#
# - Create an immutable dataclass `Course` with fields `code` and `title`.
# - Show that two equal course objects collapse to one element in a set.
# - Use the dataclass configuration rather than writing `__eq__` yourself.

# %%
from dataclasses import dataclass

# Your code here

# %% [markdown]
# ## 10. Safe Average with Exceptions
#
# **Techniques:** raising exceptions well, assertions and invariants
#
# - Write `safe_average(values)` that returns the arithmetic mean of a non-empty sequence of numbers.
# - Raise `ValueError` for an empty sequence.
# - Raise `TypeError` if any item is not numeric.

# %%
def safe_average(values):
    # Your code here
    pass


print(safe_average([10, 20, 30]))

# %% [markdown]
# ## 11. Pathlib File Summary
#
# **Techniques:** pathlib, safe file-handling patterns
#
# - Write `write_summary(lines)` that writes the provided lines to `GENERATED_DIR / "summary.txt"`.
# - Return a tuple of `(path, line_count, character_count)`.
# - Use `pathlib` and UTF-8 explicitly.

# %%
def write_summary(lines: list[str]):
    # Your code here
    pass


print(write_summary(["alpha", "beta", "gamma"]))

# %% [markdown]
# ## 12. JSON Serialization Task
#
# **Techniques:** json
#
# - Write a function `save_scores(records)` where `records` is a list of dicts.
# - Save the records as pretty-printed JSON to `GENERATED_DIR / "scores.json"`.
# - Read the file back and return the deserialized object.

# %%
def save_scores(records: list[dict]):
    # Your code here
    pass


records = [{"name": "Alice", "score": 91}, {"name": "Bob", "score": 84}]
print(save_scores(records))

# %% [markdown]
# ## 13. Counter-Based Frequency Report
#
# **Techniques:** collections.Counter
#
# - Write `top_words(text, n=3)` that returns the `n` most common lowercase words in the text.
# - Ignore punctuation by using a regular expression.
# - Return the result in the format produced by `Counter.most_common`.

# %%
import re
from collections import Counter


def top_words(text: str, n: int = 3):
    # Your code here
    pass


text = "Python is great, and Python is readable. Readable code is great."
print(top_words(text))

# %% [markdown]
# ## 14. Iterator Pipeline
#
# **Techniques:** iterator algebra with itertools, lazy vs eager evaluation
#
# - Build a lazy pipeline that squares even numbers from `range(20)` and returns the first five results as a list.
# - Use iterator-building tools rather than a single list comprehension.
# - The final function should be named `first_five_even_squares()`.

# %%
from itertools import islice


def first_five_even_squares():
    # Your code here
    pass


print(first_five_even_squares())

# %% [markdown]
# ## 15. Protocol-Oriented Function
#
# **Techniques:** Protocol and structural typing
#
# - Define a `Protocol` named `Renderable` with a `render()` method returning `str`.
# - Write a function `render_all(items)` that accepts a list of renderable items and returns a list of strings.
# - Demonstrate it with two unrelated classes that both satisfy the protocol.

# %%
from typing import Protocol

# Your code here

# %% [markdown]
# ## 16. Enum-Based State Machine
#
# **Techniques:** enum
#
# - Define an enum `Status` with `TODO`, `DOING`, and `DONE`.
# - Write `next_status(status)` that advances TODO -> DOING -> DONE and keeps DONE unchanged.
# - Return enum members, not strings.

# %%
from enum import Enum

# Your code here

# %% [markdown]
# ## 17. Logging Wrapper Decorator
#
# **Techniques:** decorators, logging
#
# - Configure simple logging and write a decorator `log_calls`.
# - When a decorated function is called, log the function name before execution.
# - Demonstrate it on a small function such as `add(a, b)`.

# %%
import logging

# Your code here

# %% [markdown]
# ## 18. Dataclass Validation with Property
#
# **Techniques:** properties, dataclasses
#
# - Create a class `Temperature` storing Celsius internally.
# - Expose a property `celsius` that rejects values below absolute zero.
# - Show both a successful update and a failing one handled with `try/except`.

# %%
class Temperature:
    # Your code here
    pass

# %% [markdown]
# ## 19. Doctest-Friendly Utility
#
# **Techniques:** doctests
#
# - Write a function `slugify(text)` with a docstring containing two doctest examples.
# - The function should lowercase text, split on whitespace, and join tokens with hyphens.
# - Demonstrate the function on one additional call.

# %%
def slugify(text: str) -> str:
    """Your doctest examples here."""
    # Your code here
    pass


print(slugify("Python Course Notes"))

# %% [markdown]
# ## 20. Small Unit Test Suite
#
# **Techniques:** unittest
#
# - Write a function `is_even(n)` and a `unittest.TestCase` class with at least three assertions covering normal behavior.
# - Include one negative number case.
# - Run the test suite from the notebook cell.

# %%
import unittest


def is_even(n: int) -> bool:
    # Your code here
    pass


class TestIsEven(unittest.TestCase):
    # Your code here
    pass


unittest.TextTestRunner().run(unittest.defaultTestLoader.loadTestsFromTestCase(TestIsEven))
