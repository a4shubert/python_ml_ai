# %% [markdown]
# # Machine Learning Index
#
# This notebook is now only a table of contents. Each paragraph-level machine learning chapter lives in its own notebook inside `6_machine_learning/`. Within each notebook, every subparagraph has its own explanation and local worked example.
#
# ## Table of Contents
#
# - [6.1 Machine Learning Framing and Workflow](6_machine_learning/6.1_machine_learning_framing_and_workflow.ipynb)
# - [6.2 Data Splits, Leakage, and Validation Strategy](6_machine_learning/6.2_data_splits_leakage_and_validation_strategy.ipynb)
# - [6.3 Feature Engineering for Tabular Data](6_machine_learning/6.3_feature_engineering_for_tabular_data.ipynb)
# - [6.4 Pipelines and Reproducible Modeling](6_machine_learning/6.4_pipelines_and_reproducible_modeling.ipynb)
# - [6.5 Linear Models for Prediction](6_machine_learning/6.5_linear_models_for_prediction.ipynb)
# - [6.6 Logistic Regression and Linear Classifiers](6_machine_learning/6.6_logistic_regression_and_linear_classifiers.ipynb)
# - [6.7 Nearest Neighbors and Distance-Based Methods](6_machine_learning/6.7_nearest_neighbors_and_distance_based_methods.ipynb)
# - [6.8 Decision Trees](6_machine_learning/6.8_decision_trees.ipynb)
# - [6.9 Ensemble Methods](6_machine_learning/6.9_ensemble_methods.ipynb)
# - [6.10 Support Vector Machines](6_machine_learning/6.10_support_vector_machines.ipynb)
# - [6.11 Model Evaluation and Metric Choice](6_machine_learning/6.11_model_evaluation_and_metric_choice.ipynb)
# - [6.12 Hyperparameter Tuning and Model Selection](6_machine_learning/6.12_hyperparameter_tuning_and_model_selection.ipynb)
# - [6.13 Clustering Foundations](6_machine_learning/6.13_clustering_foundations.ipynb)
# - [6.14 k-Means and Hierarchical Clustering](6_machine_learning/6.14_k_means_and_hierarchical_clustering.ipynb)
# - [6.15 Density and Probabilistic Clustering](6_machine_learning/6.15_density_and_probabilistic_clustering.ipynb)
# - [6.16 Dimensionality Reduction and Anomaly Detection](6_machine_learning/6.16_dimensionality_reduction_and_anomaly_detection.ipynb)
# - [6.17 Classical NLP Foundations](6_machine_learning/6.17_classical_nlp_foundations.ipynb)
# - [6.18 Text Features, NLP Models, Topic Modeling, and Text Clustering](6_machine_learning/6.18_text_features_nlp_models_topic_modeling_and_text_clustering.ipynb)
