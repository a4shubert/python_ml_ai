# %% [markdown]
# # Neural Networks Index
#
# This notebook is now only a table of contents. Each paragraph-level neural-networks chapter lives in its own notebook inside `7_neural_networks/`. Within each notebook, every subparagraph has its own explanation and local worked example.
#
# The course shows one TensorFlow / Keras orientation example in `7.1`, then standardizes on PyTorch for the rest of the chapter.
#
# ## Table of Contents
#
# - [7.1 Neural Networks Framing and Use Cases](7_neural_networks/7.1_neural_networks_framing_and_use_cases.ipynb)
# - [7.2 Tensors, Shapes, and Core PyTorch Workflow](7_neural_networks/7.2_tensors_shapes_and_core_pytorch_workflow.ipynb)
# - [7.3 Linear Layers, Activations, and Network Building Blocks](7_neural_networks/7.3_linear_layers_activations_and_network_building_blocks.ipynb)
# - [7.4 Loss Functions and Optimization](7_neural_networks/7.4_loss_functions_and_optimization.ipynb)
# - [7.5 Backpropagation Without Handwaving](7_neural_networks/7.5_backpropagation_without_handwaving.ipynb)
# - [7.6 Training Loops, Validation, and Experiment Hygiene](7_neural_networks/7.6_training_loops_validation_and_experiment_hygiene.ipynb)
# - [7.7 Regularization and Generalization](7_neural_networks/7.7_regularization_and_generalization.ipynb)
# - [7.8 Feature Scaling, Initialization, and Stabilizing Training](7_neural_networks/7.8_feature_scaling_initialization_and_stabilizing_training.ipynb)
# - [7.9 Feedforward Networks for Tabular Data](7_neural_networks/7.9_feedforward_networks_for_tabular_data.ipynb)
# - [7.10 Convolutional Neural Networks](7_neural_networks/7.10_convolutional_neural_networks.ipynb)
# - [7.11 Better CNN Practice](7_neural_networks/7.11_better_cnn_practice.ipynb)
# - [7.12 Sequence Modeling Foundations](7_neural_networks/7.12_sequence_modeling_foundations.ipynb)
# - [7.13 RNNs, LSTMs, and GRUs](7_neural_networks/7.13_rnns_lstms_and_grus.ipynb)
# - [7.14 Embeddings and Text Representation](7_neural_networks/7.14_embeddings_and_text_representation.ipynb)
# - [7.15 Attention Mechanisms](7_neural_networks/7.15_attention_mechanisms.ipynb)
# - [7.16 Transformers](7_neural_networks/7.16_transformers.ipynb)
# - [7.17 Large Language Model Foundations](7_neural_networks/7.17_large_language_model_foundations.ipynb)
# - [7.18 Fine-Tuning, Evaluation, and Neural-Network Failure Modes](7_neural_networks/7.18_fine_tuning_evaluation_and_neural_network_failure_modes.ipynb)
