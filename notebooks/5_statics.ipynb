# %% [markdown]
# # Statistics Index
#
# This notebook is now only a table of contents. Each paragraph-level statistics chapter lives in its own notebook inside `5_statiscs/`. Within each notebook, every subparagraph has its own explanation and local worked example.
#
# ## Table of Contents
#
# - [5.1 Statistical Thinking for Data Analysis](5_statiscs/5.1_statistical_thinking_for_data_analysis.ipynb)
# - [5.2 Data Generating Processes and Measurement](5_statiscs/5.2_data_generating_processes_and_measurement.ipynb)
# - [5.3 Exploratory Data Analysis for Statistical Work](5_statiscs/5.3_exploratory_data_analysis_for_statistical_work.ipynb)
# - [5.4 Probability Foundations for Applied Statistics](5_statiscs/5.4_probability_foundations_for_applied_statistics.ipynb)
# - [5.5 Sampling Distributions and the Central Limit Theorem](5_statiscs/5.5_sampling_distributions_and_the_central_limit_theorem.ipynb)
# - [5.6 Confidence Intervals and Hypothesis Testing](5_statiscs/5.6_confidence_intervals_and_hypothesis_testing.ipynb)
# - [5.7 Statistical Tests in Practice](5_statiscs/5.7_statistical_tests_in_practice.ipynb)
# - [5.8 Simple and Multiple Linear Regression](5_statiscs/5.8_simple_and_multiple_linear_regression.ipynb)
# - [5.9 Regression Diagnostics and Assumption Checking](5_statiscs/5.9_regression_diagnostics_and_assumption_checking.ipynb)
# - [5.10 Generalized Linear Models](5_statiscs/5.10_generalized_linear_models.ipynb)
# - [5.11 Regularized and Robust Regression](5_statiscs/5.11_regularized_and_robust_regression.ipynb)
# - [5.12 Categorical Data Analysis and Contingency Modeling](5_statiscs/5.12_categorical_data_analysis_and_contingency_modeling.ipynb)
# - [5.13 Time Series Foundations](5_statiscs/5.13_time_series_foundations.ipynb)
# - [5.14 ARIMA and SARIMA Forecasting](5_statiscs/5.14_arima_and_sarima_forecasting.ipynb)
# - [5.15 Experimental Design and Causal Thinking](5_statiscs/5.15_experimental_design_and_causal_thinking.ipynb)
# - [5.16 Bayesian Statistics Foundations](5_statiscs/5.16_bayesian_statistics_foundations.ipynb)
# - [5.17 Bayesian Modeling with `pymc`](5_statiscs/5.17_bayesian_modeling_with_pymc.ipynb)
# - [5.18 Hierarchical Bayesian Models and Practical Interpretation](5_statiscs/5.18_hierarchical_bayesian_models_and_practical_interpretation.ipynb)
